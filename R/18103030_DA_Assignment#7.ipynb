# %%
#install.packages("ISLR")

# %%
# Load the libraries:
library(ISLR)
# Out:
# Warning message:
# "package 'ISLR' was built under R version 3.6.3"

# %%
#We can use inbuilt datasets for the experiment
names(Smarket)
# Out:
# [1] "Year"      "Lag1"      "Lag2"      "Lag3"      "Lag4"      "Lag5"
# [7] "Volume"    "Today"     "Direction"

# %%
summary(Smarket)
# Out:
#       Year           Lag1                Lag2                Lag3
#  Min.   :2001   Min.   :-4.922000   Min.   :-4.922000   Min.   :-4.922000
#  1st Qu.:2002   1st Qu.:-0.639500   1st Qu.:-0.639500   1st Qu.:-0.640000
#  Median :2003   Median : 0.039000   Median : 0.039000   Median : 0.038500
#  Mean   :2003   Mean   : 0.003834   Mean   : 0.003919   Mean   : 0.001716
#  3rd Qu.:2004   3rd Qu.: 0.596750   3rd Qu.: 0.596750   3rd Qu.: 0.596750
#  Max.   :2005   Max.   : 5.733000   Max.   : 5.733000   Max.   : 5.733000
#       Lag4                Lag5              Volume           Today
#  Min.   :-4.922000   Min.   :-4.92200   Min.   :0.3561   Min.   :-4.922000
#  1st Qu.:-0.640000   1st Qu.:-0.64000   1st Qu.:1.2574   1st Qu.:-0.639500
#  Median : 0.038500   Median : 0.03850   Median :1.4229   Median : 0.038500
#  Mean   : 0.001636   Mean   : 0.00561   Mean   :1.4783   Mean   : 0.003138
#  3rd Qu.: 0.596750   3rd Qu.: 0.59700   3rd Qu.:1.6417   3rd Qu.: 0.596750
# ...

# %%
head(Smarket)
# Out:
#   Year Lag1   Lag2   Lag3   Lag4   Lag5   Volume Today  Direction
# 1 2001  0.381 -0.192 -2.624 -1.055  5.010 1.1913  0.959 Up
# 2 2001  0.959  0.381 -0.192 -2.624 -1.055 1.2965  1.032 Up
# 3 2001  1.032  0.959  0.381 -0.192 -2.624 1.4112 -0.623 Down
# 4 2001 -0.623  1.032  0.959  0.381 -0.192 1.2760  0.614 Up
# 5 2001  0.614 -0.623  1.032  0.959  0.381 1.2057  0.213 Up
# 6 2001  0.213  0.614 -0.623  1.032  0.959 1.3491  1.392 Up

# %%
#We will use direction as a response vairable, as that shows whether the market went up or down since the previous day

# %%
#Clean the dataset 
sum(is.na(Smarket))
# Out:
# [1] 0

# %%
#. Create Train and Test dataset
#Train is equal to the year less than 2003 and test is equal to the year greater than or equal to 2003
train=Smarket$Year<2003
test=Smarket$Year>2003

# %%
summary(train)
# Out:
#    Mode   FALSE    TRUE
# logical     756     494

# %%
summary(test)
# Out:
#    Mode   FALSE    TRUE
# logical     746     504

# %% [markdown]
# ### Logistic regression is a supervised learning classification algorithm used to predict the probability of a target variable.
# ### The nature of target or dependent variable is dichotomous, which means there would be only two possible classes.

# %%
#model except that the subset is equal to 'train', which means that it fits to just the data in year less than 2003.
#Model for logistic regression is shown below:
model=glm(Direction ~ Lag1+Lag2+ Lag3, data=Smarket, family=binomial, subset=train)

# %%
model
# Out:
# Call:  glm(formula = Direction ~ Lag1 + Lag2 + Lag3, family = binomial,
#     data = Smarket, subset = train)
#
# Coefficients:
# (Intercept)         Lag1         Lag2         Lag3
#    -0.15103     -0.04038     -0.01983     -0.01080
#
# Degrees of Freedom: 493 Total (i.e. Null);  490 Residual
# Null Deviance:	    682.2
# Residual Deviance: 681.6 	AIC: 689.6

# %%
#We predict the values of the test dataset 
prob=predict(model, newdata=Smarket[test,],type="response")
pred=ifelse(prob>0.5 ,"Up","Down")
pred
# Out:
#    747    748    749    750    751    752    753    754    755    756    757
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
#    758    759    760    761    762    763    764    765    766    767    768
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
#    769    770    771    772    773    774    775    776    777    778    779
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
#    780    781    782    783    784    785    786    787    788    789    790
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
#    791    792    793    794    795    796    797    798    799    800    801
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
#    802    803    804    805    806    807    808    809    810    811    812
# "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down" "Down"
# ...

# %% [markdown]
# ## Measure Performance
#
# We can compute an accuracy measure for classification task with the confusion matrix. The confusion matrix is a better choice to evaluate the classification performance. The general idea is to count the number of times True instances are classified are False. Confusion matrix is shown below:

# %%
Direct_2003=Smarket$Direction[test]

# %%
table(pred,Direct_2003)
# Out:
#       Direct_2003
# pred   Down  Up
#   Down  223 281

# %%
mean(pred==Direct_2003)
# Out:
# [1] 0.4424603

# %% [markdown]
# #### We got a classification rate of 44.2%
